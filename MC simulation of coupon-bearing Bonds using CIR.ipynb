# %% [markdown]
# ## Monte carlo simulation of coupon-bearing bonds using CIR

# %%
import numpy as np
import pandas as pd
import edhec_risk_ins as eri
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
eri.bond_price(5,100,.05,12,.03)
# Out:
# 0    109.275393
# dtype: float64

# %%
rates,zc_prices=eri.cir_1(10,500,b=.03,r_0=.03)

# %%
eri.bond_price(5,100,.05,12,rates.iloc[0][[1,2,3]]) #initial rate,first 3 scenarios
# Out:
# 1    109.275393
# 2    109.275393
# 3    109.275393
# dtype: float64

# %%
eri.bond_price(5,100,.05,12,rates.iloc[1][[1,2,3]])
# Out:
# 1    106.953199
# 2    110.486151
# 3    107.063348
# dtype: float64

# %%
rates[[1,2,3]].head()
# Out:
#           1         2         3
# 0  0.030000  0.030000  0.030000
# 1  0.034828  0.027527  0.034596
# 2  0.030616  0.028056  0.034194
# 3  0.030736  0.029569  0.035852
# 4  0.030362  0.030029  0.040882

# %%
eri.bond_price(10,100,.05,12,rates[[1,2,3,4]]).plot(legend=False,figsize=(15,6))
